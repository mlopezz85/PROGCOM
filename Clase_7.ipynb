# %% [markdown]
# <a href="https://colab.research.google.com/github/mlopezz85/PROGCOM/blob/main/Clase_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DICCIONARIOS
# Listas donde se pueden guardar diferentes tipos de datos. Son mutables o modificables.
# Es una colección de elementos donde cada uno tiene una key o llave (inmutable) y asociada tiene un value o valor.
# Propiedades:
# * Diámicos: Pueden mofificarse en tamaño.
# *Sohn indexados desde las llaves.
# *Pueden ser anidados.
#
# Suponiendo que se tiene la lista a=[]
# a.append(loquesedeseaagregar)
#
# O para modificar los valores dentro de la lista
# a[posicion_modificar]=valor_modificado
#
# Sintáxis
# ```
# diccionario={}
# diccionario={llave:valor,llave2:valor2,...,llaven:valorn}
#
# ```

# %%
#EJEMPLO COMO SI FUERA UN MESERO
#Entonces, la mesa 1 pidió:
pedido={1:["hamburguesa","pizza","perro","gaseosa","pola","agua"],
        2:["sushi","spaguetti","gaseosa","jugo"],
        3:["ensalada","agua"]}

# %%
#Considerando el ejercicio de la clase pasada de las nota y nombres:
construtores={"nombres":["Ana","Valerie","Roxane","Julián","Mayra"],
              "notas":[0.1,4,2,4.9,4.9]}

# %%
print(pedido)
# Out:
# {1: ['hamburguesa', 'pizza', 'perro', 'gaseosa', 'pola', 'agua'], 2: ['sushi', 'spaguetti', 'gaseosa', 'jugo'], 3: ['ensalada', 'agua']}

# %%
pedido
# Out:
# {1: ['hamburguesa', 'pizza', 'perro', 'gaseosa', 'pola', 'agua']}

# %%
#Quiero saber que pidió la mesa 1
pedido[1]
# Out:
# ['hamburguesa', 'pizza', 'perro', 'gaseosa', 'pola', 'agua']

# %%
#Determinar si cierto valor está dentro de uno de las keys del diccionario.
if "perro" in pedido[1]:
  print("Si pidieron perro.")
else:
  print("No pidieron perro.")
# Out:
# Si pidieron perro.

# %%
#Como saber cuales son los métodos de una lista/ como acceder
pedido.
#automáticamente sale la lista de todos los métodos

# %%
#Ejemplo. Otra manera de imprimir
pedido.get(1)

# %%
print(construtores.get("notas"))
# Out:
# [0.1, 4, 2, 4.9, 4.9]

# %%
#Saber quienes perdieron la materia
construtores["notas"]
for c in construtores["notas"]:
  if c<3:print("Perdió la materia.")
  else:print("Ganó la materia.")
#
# Out:
# Perdió la materia.
# Ganó la materia.
# Perdió la materia.
# Ganó la materia.
# Ganó la materia.

# %%
#Como si fuera lo que vimos en la clase pasada
for x in construtores["notas"]:
  if x<3:print(f"{construtores["nombres"].index(c)} Perdió la materia.")
  else:print(f"{construtores[x]} Ganó la materia.")



#
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6475/2322713287.py in <cell line: 0>()
#       1 #Como si fuera lo que vimos en la clase pasada
#       2 for x in construtores["notas"]:
# ----> 3   if x<3:print(f"{construtores[x]} Perdió la materia.")
#       4   else:print(f"{construtores[x]} Ganó la materia.")
#       5
#
# KeyError: 0.1
