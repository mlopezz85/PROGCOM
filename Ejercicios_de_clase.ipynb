# %% [markdown]
# a)	Solicitar que un usuario elija la operación entre dos números que desee realizar y calcule su resultado. Las operaciones a elegir son:
# 	Suma
# 	Resta
# 	Multiplicación
# 	División.
# 	Módulo.

# %%
#Ejercicios
#Nivel 1
#Ejercicio 1 - match case
"""
opcion=""
n1=0
n2=0
r=0
print("Ingrese una opción de las siguientes que se mencionan: \n 1. Suma \n 2. Resta \n 3. Multiplicación \n 4. División \n 5. Módulo")
opcion=input("Digite una opción: ")
match opcion:

  case "1":
    n1=float(input("Ingrese el primer número: "))
    n2=float(input("Ingrese el segundo número: "))
    r=n1+n2
    print(f"El resultado de la suma fue {r}.")
  case "2":
    n1=float(input("Ingrese el primer número: "))
    n2=float(input("Ingrese el segundo número: "))
    r=n1-n2
    print(f"El resultado de la resta fue {r}.")
  case "3":
    n1=float(input("Ingrese el primer número: "))
    n2=float(input("Ingrese el segundo número: "))
    r=n1*n2
    print(f"El resultado de la multiplicación fue {r}.")
  case "4":
    n1=float(input("Ingrese el primer número: "))
    n2=float(input("Ingrese el segundo número: "))
    r=n1/n2
    print(f"El resultado de la división fue {r}.")
  case "5":
    n1=float(input("Ingrese el primer número: "))
    n2=float(input("Ingrese el segundo número: "))
    r=n1%n2
    print(f"El resultado del módulo fue {r}.")
"""
#if
opcion=""
n1=0
n2=0
r=0
print("Ingrese una opción de las siguientes que se mencionan: \n 1. Suma \n 2. Resta \n 3. Multiplicación \n 4. División \n 5. Módulo")
opcion=input("Digite una opción: ")
if opcion=="1":
  n1=float(input("Ingrese el primer número: "))
  n2=float(input("Ingrese el segundo número: "))
  r=n1+n2
  print(f"El resultado de la suma fue {r}.")
if opcion=="2":
  n1=float(input("Ingrese el primer número: "))
  n2=float(input("Ingrese el segundo número: "))
  r=n1-n2
  print(f"El resultado de la resta fue {r}.")
if opcion=="3":
  n1=float(input("Ingrese el primer número: "))
  n2=float(input("Ingrese el segundo número: "))
  r=n1*n2
  print(f"El resultado de la multiplicación fue {r}.")
if opcion=="4":
  n1=float(input("Ingrese el primer número: "))
  n2=float(input("Ingrese el segundo número: "))
  r=n1/n2
  print(f"El resultado de la división fue {r}.")
if opcion=="5":
  n1=float(input("Ingrese el primer número: "))
  n2=float(input("Ingrese el segundo número: "))
  r=n1%n2
  print(f"El resultado del módulo fue {r}.")

#elif
opcion=""
n1=0
n2=0
r=0
print("Ingrese una opción de las siguientes que se mencionan: \n 1. Suma \n 2. Resta \n 3. Multiplicación \n 4. División \n 5. Módulo")
opcion=input("Digite una opción: ")
if opcion=="1":
  n1=float(input("Ingrese el primer número: "))
  n2=float(input("Ingrese el segundo número: "))
  r=n1+n2
  print(f"El resultado de la suma fue {r}.")
elif opcion=="2":
  n1=float(input("Ingrese el primer número: "))
  n2=float(input("Ingrese el segundo número: "))
  r=n1-n2
  print(f"El resultado de la resta fue {r}.")
elif opcion=="3":
  n1=float(input("Ingrese el primer número: "))
  n2=float(input("Ingrese el segundo número: "))
  r=n1*n2
  print(f"El resultado de la multiplicación fue {r}.")
elif opcion=="4":
  n1=float(input("Ingrese el primer número: "))
  n2=float(input("Ingrese el segundo número: "))
  r=n1/n2
  print(f"El resultado de la división fue {r}.")
else:
  n1=float(input("Ingrese el primer número: "))
  n2=float(input("Ingrese el segundo número: "))
  r=n1%n2
  print(f"El resultado del módulo fue {r}.")

LVL 2


# Datos
num1 = float(input("Introduce el primer número: "))
num2 = float(input("Introduce el segundo número: "))
num3 = float(input("Introduce el tercer número: "))

# Condiciones
if (num1 >= num2) and (num1 >= num3):
   mayor = num1
elif (num2 >= num1) and (num2 >= num3):
   mayor = num2
else:
   mayor = num3

print("El número más grande es", mayor)




# Datos
num1 = float(input("Introduce el primer número: "))
num2 = float(input("Introduce el segundo número: "))
num3 = float(input("Introduce el tercer número: "))

# Condiciones
match True:
    case _ if (num1 >= num2) and (num1 >= num3):
        mayor = num1
    case _ if (num2 >= num1) and (num2 >= num3):
        mayor = num2
    case _:
        mayor = num3

print("El número más grande es", mayor)
# Out:
# Ingrese una opción de las siguientes que se mencionan:
#  1. Suma
#  2. Resta
#  3. Multiplicación
#  4. División
#  5. Módulo
# Digite una opción: 1
# Ingrese el primer número: 3
# Ingrese el segundo número: 4
# El resultado de la suma fue 7.0.
